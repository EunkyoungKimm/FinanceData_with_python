# %% [markdown]
# # Prophet

# %% [markdown]
# - 예측 모델을 만든다!
# - 모델이 미래를 예측 하는 것..
# - 모델 학습하기 > 예측하기 > 평가하기

# %% [markdown]
# - 시간은 ds로, 예측할건 y로 바꿔줘야 .. 형식을 맞춰줘야 동작한다! > y 일변량...
# - datetime 자료형으로 바꾸기(시간으로 바꿔주기)

# %% [markdown]
# - Make Future Dataframe : 예측할 데이터 공간 만들어주기..
# - Predict : data로 만든 model로 아래 데이터 예측해보기
# - Visualize : 예측이 잘 되었나 보기 위해서 시각화

# %% [markdown]
# - 파란색점이 예측한 데이터, 까만점이 실제 데이터..
# - initial

# %%
# !pip install Cython
# Out:
# ...
#   Using cached Cython-0.29.33-py2.py3-none-any.whl (987 kB)
# ...

# %%
# !pip install fbprophet
# Out:
# ...
#   Using cached fbprophet-0.7.1.tar.gz (64 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached cmdstanpy-0.9.5-py3-none-any.whl (37 kB)
# ...
#   Using cached pystan-3.6.0-py3-none-any.whl (13 kB)
# ...
#   Using cached LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# ...
#   Using cached convertdate-2.4.0-py3-none-any.whl (47 kB)
# ...
#   Using cached holidays-0.19-py3-none-any.whl (208 kB)
# ...
#   Using cached setuptools_git-1.2-py2.py3-none-any.whl (10 kB)
# ...
#   Using cached PyMeeus-0.5.12.tar.gz (5.8 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# ...
#   Using cached hijri_converter-2.2.4-py3-none-any.whl (14 kB)
# ...
#   Using cached ephem-4.1.4-cp39-cp39-win_amd64.whl (1.4 MB)
# ...
#   Using cached pysimdjson-5.0.2-cp39-cp39-win_amd64.whl (156 kB)
# ...
#   Using cached pystan-3.5.0-py3-none-any.whl (13 kB)
# ...

# %% [markdown]
# - 파이썬 버전 3.9 아래여야 됨! >>> 해보기!

# %% [markdown]
# - VScode 쓰자! 데이터분석이나 머신러닝.. >> ipynb / 백앤드..>> .py >>>>>>>>>>>>> 둘다 지원함!!
# - 코랩(교육용으로 좋음) > 환경설정 굳이 따로 안해도 동일한 환경에서 배울 수 있으니까!

# %% [markdown]
# - 일단 코랩으로 가자!

# %% [markdown]
# - MS : 월초
