# %% [markdown]
# ## PPT

# %% [markdown]
# - '현재상황이 어떻다' >> 기술통계 (데이터 분석..하면 이거)
# - 확률적으로 예측 >> Prophet, 머신러닝..
# - 기술통계를 가지고 추론하여 미래를 예측하는게 추리 통계..

# %% [markdown]
# - 데이터들이 얼마나 모여있는지, 얼마나 퍼져 있는지를 분석하는게 데이터 분석!

# %% [markdown]
# - 국민 1인당 평균 소득 분석 >> 평균만 보면 정확한 분석할 수 없음!

# %% [markdown]
# - groupby해서 보거나, 테이블 형태로 해서 보는것 >> 도수분포표
# - 도수분포표를 막대 그래프로 시각화해서 보는 것 >>> 히스토그램(그림 기억해두기! - 정규분포, 비대칭분포, 이상값이 존재한 경우, 한계값에서 벗어난 값을 모두 한계값으로 대신한 경우)
# - 정규분포를 따른다고 가정했을 때, 가운데 0 이 평균.. > 평균이 60, 표준편차가 10이면 평균으로부터 1표준편차 떨어져있다 >> 50 ~ 70점이 68%... 이런거임!! 이것만 알아도 세상을 통계적으로 잘볼수o / 평균이 50000원, 표준편차가 5000원인데 이게 정규분포를 따른다고 가정하면 45000 ~ 55000사이에 움직일 가능성이 68%라는 것!(4만원 >> 가격이 상대적으로 싸다 / 6만원 >> 가격이 상대적으로 비쌈 ) 이걸 이용해서 쌀때 사고, 비쌀때 파는걸 볼리저밴드!?

# %% [markdown]
# 이상치, Box plot
# - 분산도에서 사분편차&표준편차를 많이 씀!
# - quatile은 1/4 / Q2-Q3 , Q4-Q3 >> 이런걸 사분편차라고 함!
# - 25%~75% >> IQR
# - 이상치 = outlier = * (얘네를 위한 예측이 필요한게 아님(얘네때문에 예측이 이상해짐).. >> 이상치 판단을 하고 없애주거나 값을 바꿔줘야 함) >> +1.5 X IQR / -1.5 X IQR(이상치의 양에 따라서.. 1.5했는데.. 이상치 너무 많으면 3.0하기도함...(적으면 또 값을 바꿔주기도 할수도있겠지?)
# - Box whisker(수염) >> 이게 뭐임?!
# - 쓰레기는 none값 , 이상치임 >>  (쓰레기를 넣으면 쓰레기가 나옴) 그래서 값을 바꾸거나 or 없애줘야 함!!(삭제하는게 제일 깔끔하고, 데이터가 부족하거나 대체해야 될때는 다른 값으로 대체해줌)
# - box plot을 그리면 데이터의 분포를 쉽게 파악할 수 있다는 장점이 있음
# - 가운데 값에 비해 q2가 오른쪽에 치우쳐져 있으면 .. 뭐라고?!

# %% [markdown]
# 공분산
# - 분석할때는 그렇게 많이 쓰이진 않음. 포트폴리오 할때 씀
# - 공통된 분산이 작다(부호가 서로 다를때.. 같은 방향이 아니다...)

# %% [markdown]
# 상관계수
# - 꼭 기억하기!
# - 상관관계가 크다, 작다(같이 움직이냐 아니냐)
# - `-1 ~ 1` (0에 가까울수록 관계가 없는 것에 가깝다! 관계가 없다!)
# - 몸무게, 키 >> 상관관계 어느정도 있다!!(몸무게 많으면 키크다!)
# - ex. 삼성전자 주가&삼성전자 주주의 우울감 >> -1 에 가까움

# %% [markdown]
# - 포토폴리오에서 `위험을 낮추는 측면`에서는 상관관계가 0인, 상관없는 종목들을 넣어주는게 굿! 수익률 측면에서는 아닐 수도 있음! >> 종목간의 관계..
# - 상관관계 0 >> 상관관계 적을수록 >> 위험적음!

# %% [markdown]
# ### 수익률과 위험

# %% [markdown]
# - 표준편차가 크다 > 리스크가 크다 > 데이터의 퍼짐이 크다(왔다갔다 폭이 크다 > 가격이 왔다갔다 많이 함!)
# - 수익률의 평균이 크다(평균적으로 좋은 수익률을 내준다) > 수익률이 높다
# - naver(성장형 주식) / KT&G(배당형, 안정적인 주심) > 네이버는 B에 가까움(가격이 높아졌다 낮아졌다 가격변동 큼) / KT&G는 가격변동이 적음... 아닐수도..

# %% [markdown]
# 복리 수익률
# - 단리와 차이 > 복리는 이자에다가 이자가 붙음!!

# %% [markdown]
# 로그 수익률
# - 계산이 편리!
# - 단순수익률과 비교했을 때 구분됨. 왜 써야 하는지 알 수 있음.. > 오름폭과 내림폭 수익률에 대한 계산 정확하게 할 수 있음!!!
# - ex.200원에서 50% 떨어지면 100원, 다시 50%오르면 150원.. log return하면 이럴일x
# - 가장 중요한건 돈을 잃지 않는 것!(

# %% [markdown]
# 수익률 계산 4가지
# - 복리수익률, 누적 수익률, 연..., log 수익률
