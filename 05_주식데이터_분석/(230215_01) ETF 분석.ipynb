# %%
# !pip install pykrx
# !pip install -U finance-datareader

# %%
from pykrx import stock
import FinanceDataReader as fdr
import pandas as pd

# %%
ETF_name = fdr.StockListing('ETF/KR')
ETF_name.head()
# Out:
#    Symbol                   Name
# 0  069500              KODEX 200
# 1  357870    TIGER CD금리투자KIS(합성)
# 2  371460  TIGER 차이나전기차SOLACTIVE
# 3  423160    KODEX KOFR금리액티브(합성)
# 4  252670       KODEX 200선물인버스2X

# %%
ETF_list = ['KODEX 은행','KODEX 2차전지산업','TIGER 중국소비테마']

# %%
ETF = ETF_name[ETF_name['Name'].isin(ETF_list)]
ETF
# Out:
#      Symbol          Name
# 15   305720  KODEX 2차전지산업
# 68   091170      KODEX 은행
# 105  150460  TIGER 중국소비테마

# %%
empty_df = pd.DataFrame()
for idx, values in ETF.iterrows():
  df = fdr.DataReader(values['Symbol'], '2021-01-01')
  df['Name'] = values['Name']
  empty_df = pd.concat([empty_df, df], axis = 0)

# %%
empty_df['Name'].unique()
# Out:
# array(['KODEX 2차전지산업', 'KODEX 은행', 'TIGER 중국소비테마'], dtype=object)

# %%
len(empty_df)
# Out:
# 1575

# %%
df2 = fdr.DataReader('150460', '2021-01-01')
len(df2)
# Out:
# 525

# %%
subset_etf = empty_df.copy()
subset_etf.head()
# Out:
#              Open   High    Low  Close    Volume    Change          Name
# Date
# 2021-01-04  15769  17130  15520  17036   7065645  0.097539  KODEX 2차전지산업
# 2021-01-05  16862  17304  16708  17304   6546719  0.015731  KODEX 2차전지산업
# 2021-01-06  17582  17915  17159  17494   8424665  0.010980  KODEX 2차전지산업
# 2021-01-07  17830  18193  17562  18164   7309759  0.038299  KODEX 2차전지산업
# 2021-01-08  18511  18988  18163  18909  10077189  0.041015  KODEX 2차전지산업

# %%
import plotly.express as px
fig = px.line(subset_etf, x=subset_etf.index, y="Close", color='Name')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d3bc1d32-55fb-45f4-8f73-fc85e5cd23a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3bc1d32-55fb-45f4-8f73-fc85e5cd23a9")) {                    Plotly.newPlot(                        "d3bc1d32-55fb-45f4-8f73-fc85e5cd23a9",                        [{"hovertemplate":"Name=KODEX 2\ucc28\uc804\uc9c0\uc0b0\uc5c5<br>Date=%{x}<br>Close=%{y}<extra></extra>","legendgroup":"KODEX 2\ucc28\uc804\uc9c0\uc0b0\uc5c5","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"KODEX 2\ucc28\uc804\uc9c0\uc0b0\uc5c5","showlegend":true,"x":["2021-01-04T00:00:00","2021-01-05T00:00:00","2021-01-06T00:00:00","2021-01-07T00:00:00","2021-01-08T00:00:00","2021-01-11T00:00:00","2021-01-12T00:00:00","2021-01-13T00:00:00","2021-01-14T00:00:00","2021-01-15T00:00:00","2021-01-18T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-25T00:00:00","2021-01-26T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-05T00:00:00","2021-02-08T00:00:00","2021-02-09T00:00:00","2021-02-10T00:00:00","2021-02-15T00:00:00","2021-02-16T00:00:00","2021-02-17T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-22T00:00:00","2021-02-23T00:00:00","2021-02-24T00:00:00","2021-02-25T00:00:00","2021-02-26T00:00:00","2021-03-02T00:00:00","2021-03-03T00:00:00","2021-03-04T00:00:00","2021-03-05T00:00:00","2021-03-08T00:00:00","2021-03-09T00:00:00","2021-03-10T00:00:00","2021-03-11T00:00:00","2021-03-12T00:00:00","2021-03-15T00:00:00","2021-03-16T00:00:00","2021-03-17T00:00:00","2021-03-18T00:00:00","2021-03-19T00:00:00","2021-03-22T00:00:00","2021-03-23T00:00:00","2021-03-24T00:00:00","2021-03-25T00:00:00","2021-03-26T00:00:00","2021-03-29T00:00:00","2021-03-30T00:00:00","2021-03-31T00:00:00","2021-04-01T00:00:00","2021-04-02T00:00:00","2021-04-05T00:00:00","2021-04-06T00:00:00","2021-04-07T00:00:00","2021-04-08T00:00:00","2021-04-09T00:00:00","2021-04-12T00:00:00","2021-04-13T00:00:00","2021-04-14T00:00:00","2021-04-15T00:00:00","2021-04-16T00:00:00","2021-04-19T00:00:00","2021-04-20T00:00:00","2021-04-21T00:00:00","2021-04-22T00:00:00","2021-04-23T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-13T00:00:00","2021-05-14T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-20T00:00:00","2021-05-21T00:00:00","2021-05-24T00:00:00","2021-05-25T00:00:00","2021-05-26T00:00:00","2021-05-27T00:00:00","2021-05-28T00:00:00","2021-05-31T00:00:00","2021-06-01T00:00:00","2021-06-02T00:00:00","2021-06-03T00:00:00","2021-06-04T00:00:00","2021-06-07T00:00:00","2021-06-08T00:00:00","2021-06-09T00:00:00","2021-06-10T00:00:00","2021-06-11T00:00:00","2021-06-14T00:00:00","2021-06-15T00:00:00","2021-06-16T00:00:00","2021-06-17T00:00:00","2021-06-18T00:00:00","2021-06-21T00:00:00","2021-06-22T00:00:00","2021-06-23T00:00:00","2021-06-24T00:00:00","2021-06-25T00:00:00","2021-06-28T00:00:00","2021-06-29T00:00:00","2021-06-30T00:00:00","2021-07-01T00:00:00","2021-07-02T00:00:00","2021-07-05T00:00:00","2021-07-06T00:00:00","2021-07-07T00:00:00","2021-07-08T00:00:00","2021-07-09T00:00:00","2021-07-12T00:00:00","2021-07-13T00:00:00","2021-07-14T00:00:00","2021-07-15T00:00:00","2021-07-16T00:00:00","2021-07-19T00:00:00","2021-07-20T00:00:00","2021-07-21T00:00:00","2021-07-22T00:00:00","2021-07-23T00:00:00","2021-07-26T00:00:00","2021-07-27T00:00:00","2021-07-28T00: ...

# %%
subset_etf
# Out:
#              Open   High    Low  Close    Volume    Change          Name
# Date
# 2021-01-04  15769  17130  15520  17036   7065645  0.097539  KODEX 2차전지산업
# 2021-01-05  16862  17304  16708  17304   6546719  0.015731  KODEX 2차전지산업
# 2021-01-06  17582  17915  17159  17494   8424665  0.010980  KODEX 2차전지산업
# 2021-01-07  17830  18193  17562  18164   7309759  0.038299  KODEX 2차전지산업
# 2021-01-08  18511  18988  18163  18909  10077189  0.041015  KODEX 2차전지산업
# ...           ...    ...    ...    ...       ...       ...           ...
# 2023-02-09   7335   7490   7330   7400     53518  0.005435  TIGER 중국소비테마
# 2023-02-10   7400   7490   7345   7475     62758  0.010135  TIGER 중국소비테마
# 2023-02-13   7495   7515   7375   7425     56764 -0.006689  TIGER 중국소비테마
# 2023-02-14   7410   7480   7410   7470     93910  0.006061  TIGER 중국소비테마
# 2023-02-15   7540   7540   7350   7375     22094 -0.012718  TIGER 중국소비테마
#
# [1575 rows x 7 columns]

# %%
etf = pd.pivot_table(index = subset_etf.index, columns = 'Name', values = 'Close', data = subset_etf)
etf.head()
# Out:
# Name        KODEX 2차전지산업  KODEX 은행  TIGER 중국소비테마
# Date
# 2021-01-04         17036      5654          7556
# 2021-01-05         17304      5727          7511
# 2021-01-06         17494      5796          7496
# 2021-01-07         18164      6017          7521
# 2021-01-08         18909      6054          7541

# %%
etf_index = (etf / etf.iloc[0]) * 100
etf_index.head()
# Out:
# Name        KODEX 2차전지산업    KODEX 은행  TIGER 중국소비테마
# Date
# 2021-01-04    100.000000  100.000000    100.000000
# 2021-01-05    101.573139  101.291121     99.404447
# 2021-01-06    102.688425  102.511496     99.205929
# 2021-01-07    106.621273  106.420233     99.536792
# 2021-01-08    110.994365  107.074637     99.801482

# %%
melt_etf_index = etf_index.reset_index().melt(id_vars = 'Date')
melt_etf_index.head()
# Out:
#         Date          Name       value
# 0 2021-01-04  KODEX 2차전지산업  100.000000
# 1 2021-01-05  KODEX 2차전지산업  101.573139
# 2 2021-01-06  KODEX 2차전지산업  102.688425
# 3 2021-01-07  KODEX 2차전지산업  106.621273
# 4 2021-01-08  KODEX 2차전지산업  110.994365

# %%
import plotly.express as px
fig = px.line(melt_etf_index, x='Date', y="value", color='Name')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b7e64183-0584-4183-93c8-db22f3bdf773" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7e64183-0584-4183-93c8-db22f3bdf773")) {                    Plotly.newPlot(                        "b7e64183-0584-4183-93c8-db22f3bdf773",                        [{"hovertemplate":"Name=KODEX 2\ucc28\uc804\uc9c0\uc0b0\uc5c5<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"KODEX 2\ucc28\uc804\uc9c0\uc0b0\uc5c5","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"KODEX 2\ucc28\uc804\uc9c0\uc0b0\uc5c5","showlegend":true,"x":["2021-01-04T00:00:00","2021-01-05T00:00:00","2021-01-06T00:00:00","2021-01-07T00:00:00","2021-01-08T00:00:00","2021-01-11T00:00:00","2021-01-12T00:00:00","2021-01-13T00:00:00","2021-01-14T00:00:00","2021-01-15T00:00:00","2021-01-18T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-25T00:00:00","2021-01-26T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-05T00:00:00","2021-02-08T00:00:00","2021-02-09T00:00:00","2021-02-10T00:00:00","2021-02-15T00:00:00","2021-02-16T00:00:00","2021-02-17T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-22T00:00:00","2021-02-23T00:00:00","2021-02-24T00:00:00","2021-02-25T00:00:00","2021-02-26T00:00:00","2021-03-02T00:00:00","2021-03-03T00:00:00","2021-03-04T00:00:00","2021-03-05T00:00:00","2021-03-08T00:00:00","2021-03-09T00:00:00","2021-03-10T00:00:00","2021-03-11T00:00:00","2021-03-12T00:00:00","2021-03-15T00:00:00","2021-03-16T00:00:00","2021-03-17T00:00:00","2021-03-18T00:00:00","2021-03-19T00:00:00","2021-03-22T00:00:00","2021-03-23T00:00:00","2021-03-24T00:00:00","2021-03-25T00:00:00","2021-03-26T00:00:00","2021-03-29T00:00:00","2021-03-30T00:00:00","2021-03-31T00:00:00","2021-04-01T00:00:00","2021-04-02T00:00:00","2021-04-05T00:00:00","2021-04-06T00:00:00","2021-04-07T00:00:00","2021-04-08T00:00:00","2021-04-09T00:00:00","2021-04-12T00:00:00","2021-04-13T00:00:00","2021-04-14T00:00:00","2021-04-15T00:00:00","2021-04-16T00:00:00","2021-04-19T00:00:00","2021-04-20T00:00:00","2021-04-21T00:00:00","2021-04-22T00:00:00","2021-04-23T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-13T00:00:00","2021-05-14T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-20T00:00:00","2021-05-21T00:00:00","2021-05-24T00:00:00","2021-05-25T00:00:00","2021-05-26T00:00:00","2021-05-27T00:00:00","2021-05-28T00:00:00","2021-05-31T00:00:00","2021-06-01T00:00:00","2021-06-02T00:00:00","2021-06-03T00:00:00","2021-06-04T00:00:00","2021-06-07T00:00:00","2021-06-08T00:00:00","2021-06-09T00:00:00","2021-06-10T00:00:00","2021-06-11T00:00:00","2021-06-14T00:00:00","2021-06-15T00:00:00","2021-06-16T00:00:00","2021-06-17T00:00:00","2021-06-18T00:00:00","2021-06-21T00:00:00","2021-06-22T00:00:00","2021-06-23T00:00:00","2021-06-24T00:00:00","2021-06-25T00:00:00","2021-06-28T00:00:00","2021-06-29T00:00:00","2021-06-30T00:00:00","2021-07-01T00:00:00","2021-07-02T00:00:00","2021-07-05T00:00:00","2021-07-06T00:00:00","2021-07-07T00:00:00","2021-07-08T00:00:00","2021-07-09T00:00:00","2021-07-12T00:00:00","2021-07-13T00:00:00","2021-07-14T00:00:00","2021-07-15T00:00:00","2021-07-16T00:00:00","2021-07-19T00:00:00","2021-07-20T00:00:00","2021-07-21T00:00:00","2021-07-22T00:00:00","2021-07-23T00:00:00","2021-07-26T00:00:00","2021-07-27T00:00:00","2021-07-28T00: ...

# %% [markdown]
# ### 종목구성 비교

# %%
ETF
# Out:
#      Symbol          Name
# 15   305720  KODEX 2차전지산업
# 68   091170      KODEX 은행
# 105  150460  TIGER 중국소비테마

# %%
df = stock.get_etf_portfolio_deposit_file('150460')
df.head()
# Out:
#           계약수        금액    비중
# 티커
# 086900   57.0  10488000  4.82
# 145720   77.0  10048500  4.44
# 002790  207.0   9014850  3.99
# 035760   87.0   8874000  3.96
# 192820  106.0   8490600  3.78

# %%
ETF_portpolio = pd.DataFrame()
for idx, values in ETF.iterrows():
  df = stock.get_etf_portfolio_deposit_file(values['Symbol'])
  df['Name'] = values['Name']
  ETF_portpolio = pd.concat([ETF_portpolio, df], axis = 0)

# %%
ETF_portpolio['Name'].unique()
# Out:
# array(['KODEX 2차전지산업', 'KODEX 은행', 'TIGER 중국소비테마'], dtype=object)

# %%
ETF_portpolio.head()
# Out:
#            계약수         금액         비중          Name
# 티커
# 006400   595.0  439705000  19.059999  KODEX 2차전지산업
# 247540  2986.0  419533000  18.879999  KODEX 2차전지산업
# 003670  1515.0  346177500  15.270000  KODEX 2차전지산업
# 373220   582.0  305550000  13.680000  KODEX 2차전지산업
# 096770  1890.0  316575000  12.930000  KODEX 2차전지산업

# %%
# 종목 수
stock_count = ETF_portpolio['Name'].value_counts()
stock_count
# Out:
# TIGER 중국소비테마    31
# KODEX 2차전지산업    26
# KODEX 은행        10
# Name: Name, dtype: int64

# %%
import plotly.express as px
fig = px.bar(stock_count, x=stock_count.index, y=stock_count.values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b711a07f-f68d-4695-9f42-be02aeb58520" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b711a07f-f68d-4695-9f42-be02aeb58520")) {                    Plotly.newPlot(                        "b711a07f-f68d-4695-9f42-be02aeb58520",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["TIGER \uc911\uad6d\uc18c\ube44\ud14c\ub9c8","KODEX 2\ucc28\uc804\uc9c0\uc0b0\uc5c5","KODEX \uc740\ud589"],"xaxis":"x","y":[31,26,10],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""} ...

# %% [markdown]
# ### 내부 구성 종목들의 비율

# %%
cor_list = fdr.StockListing('KRX')[['Code','Name']]
cor_list.head()
# Out:
#      Code      Name
# 0  005930      삼성전자
# 1  373220  LG에너지솔루션
# 2  000660    SK하이닉스
# 3  207940  삼성바이오로직스
# 4  006400     삼성SDI

# %%
cor_list_dict = cor_list.set_index('Code').to_dict()

# %%
merge_cor_name = pd.merge(left = cor_list, right = ETF_portpolio, left_on = 'Code', right_on = ETF_portpolio.index)
merge_cor_name.columns= ['티커', '종목명', '계약수', '금액', '비중', 'ETF_Name']
merge_cor_name.head()
# Out:
#        티커       종목명     계약수         금액         비중      ETF_Name
# 0  373220  LG에너지솔루션   582.0  305550000  13.680000  KODEX 2차전지산업
# 1  006400     삼성SDI   595.0  439705000  19.059999  KODEX 2차전지산업
# 2  105560      KB금융  1222.0   64766000  18.760000      KODEX 은행
# 3  055550      신한지주  1785.0   70418250  20.660000      KODEX 은행
# 4  003670    포스코케미칼  1515.0  346177500  15.270000  KODEX 2차전지산업

# %%
merge_cor_name = merge_cor_name[merge_cor_name['비중'] > 1] # 비중이 1보다 큰 데이터만 활용

# %%
etf_weight = pd.pivot_table(index = '종목명', columns = 'ETF_Name', values = '비중', data = merge_cor_name)
etf_weight.head()
# Out:
# ETF_Name  KODEX 2차전지산업  KODEX 은행  TIGER 중국소비테마
# 종목명
# BNK금융지주            NaN      2.77           NaN
# CJ CGV             NaN       NaN          2.86
# CJ ENM             NaN       NaN          3.95
# CJ제일제당             NaN       NaN          2.68
# DGB금융지주            NaN      1.68           NaN

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

labels = etf_weight.index

fig = make_subplots(1, 3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]],
                    subplot_titles=etf_weight.columns)
fig.add_trace(go.Pie(labels=labels, values=etf_weight['KODEX 2차전지산업'], scalegroup='one'), 1, 1)
fig.add_trace(go.Pie(labels=labels, values=etf_weight['KODEX 은행'], scalegroup='one'), 1, 2)
fig.add_trace(go.Pie(labels=labels, values=etf_weight['TIGER 중국소비테마'], scalegroup='one'), 1, 3)

fig.update_layout(title_text='ETF 종목 비중')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a7f2362e-5780-4e33-b4ff-0ff1c1bb853a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7f2362e-5780-4e33-b4ff-0ff1c1bb853a")) {                    Plotly.newPlot(                        "a7f2362e-5780-4e33-b4ff-0ff1c1bb853a",                        [{"labels":["BNK\uae08\uc735\uc9c0\uc8fc","CJ CGV","CJ ENM","CJ\uc81c\uc77c\uc81c\ub2f9","DGB\uae08\uc735\uc9c0\uc8fc","F&F","JB\uae08\uc735\uc9c0\uc8fc","KB\uae08\
53d","\uc5d0\ucf54\ud504\ub85c\ube44\uc5e0","\uc5d8\uc564\uc5d0\ud504","\uc601\uc6d0\ubb34\uc5ed","\uc624\ub9ac\uc628","\uc6b0\ub9ac\uae08\uc735\uc9c0\uc8fc","\uc81c\ub85c\ud22c\uc138\ube10","\uce74\uce74\uc624\ubc45\ud06c","\ucf54\uc2a4\ub9e5\uc2a4","\ucf54\uc2a4\ubaa8\uc2e0\uc18c\uc7ac","\ucf54\uc6e8\uc774","\ucf58\ud150\ud2b8\ub9ac\uc911\uc559","\ucf5c\ub9c8\ube44\uc564\uc5d0\uc774\uce58","\ud30c\ub77c\ub2e4\uc774\uc2a4","\ud3ec\uc2a4\ucf54\ucf00\ubbf8\uce7c","\ud558\ub098\uae08\uc735\uc9c0\uc8fc","\ud558\ub098\ud22c\uc5b4","\ud55c\uad6d\ucf5c\ub9c8","\ud55c\ubbf8\uc57d\ud488","\ud604\ub300\uadf8\ub9b0\ud478\ub4dc","\ud638\ud154\uc2e0\ub77c","\ud720\ub77c\ud640\ub529\uc2a4"],"scalegroup":"one","values":[2.7699999809265137,null,null,null,1.6799999475479126,null,2.299999952316284,18.760000228881836,null,null,null ...

# %%
etf_weight.fillna(0).corr() # 종목 비중 상관관계
# Out:
# ETF_Name      KODEX 2차전지산업  KODEX 은행  TIGER 중국소비테마
# ETF_Name
# KODEX 2차전지산업      1.000000 -0.146795     -0.485698
# KODEX 은행         -0.146795  1.000000     -0.474428
# TIGER 중국소비테마     -0.485698 -0.474428      1.000000

# %%
# 종목별 종가의 상관관계

etf_close = pd.pivot_table(index = 'Date', columns = 'Name', values = 'Close', data = subset_etf)
etf_cor_close = etf_close.corr()
etf_cor_close.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d8aef_row0_col0, #T_d8aef_row1_col1, #T_d8aef_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d8aef_row0_col1, #T_d8aef_row0_col2, #T_d8aef_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d8aef_row1_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_d8aef_row1_col2 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_d8aef_row2_col1 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# </style>
# <table id="T_d8aef_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Name</th>
#       <th class="col_heading level0 col0" >KODEX 2차전지산업</th>
#       <th class="col_heading level0 col1" >KODEX 은행</th>
#       <th class="col_heading level0 col2" >TIGER 중국소비테마</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8aef_level0_row0" class="row_heading level0 row0" >KODEX 2차전지산업</th>
#       <td id="T_d8aef_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d8aef_row0_col1" class="data row0 col1" >0.184370</td>
#       <td id="T_d8aef_row0_col2" class="data row0 col2" >0.104967</td>
#     </tr>
#     <tr>
#       <th id="T_d8aef_level0_row1" class="row_heading level0 row1" >KODEX 은행</th>
#       <td id="T_d8aef_row1_col0" class="data row1 col0" >0.184370</td>
#       <td id="T_d8aef_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d8aef_row1_col2" class="data row1 col2" >0.512765</td>
#     </tr>
#     <tr>
#       <th id="T_d8aef_level0_row2" class="row_heading level0 row2" >TIGER 중국소비테마</th>
#       <td id="T_d8aef_row2_col0" class="data row2 col0" >0.104967</td>
#       <td id="T_d8aef_row2_col1" class="data row2 col1" >0.512765</td>
#       <td id="T_d8aef_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
